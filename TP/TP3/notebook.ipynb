# %% [markdown]
# # TP - Labyrinth

# %%
import numpy as np

# %%
from labyrinth import display_labyrinth
from labyrinth import solve_labyrinth
from labyrinth import generate_field

# %% [markdown]
# ## Load the grid

# %%
file = "grid10.npy"
grid = np.load(file)
grid=generate_field(35,35)
start = (0,0)
h = grid.shape[0]
w = grid.shape[1]
end = (h - 1, w - 1)

# %% [markdown]
# ## Solve the labyrinth

# %%
display_labyrinth(grid, start, end)
# Out:
# No solution has been found

# %%
# Run the genetic algorithm
solution = solve_labyrinth(grid, start, end, 75)
# solution = [(0,0), (0,1), (0,2), (1,2), (1,3), (2,3), (3,3), (4,3), 
#            (5,3), (6,3), (6,4), (6,5), (6,6), (6,7), (6,8), (7,8),
#            (8,8), (9,8), (9,9)]
# Out:
# Work in progress...please wait
# the time out he is
# population generaton number : 579
# time elapsed : 75.05811476707458

# %%
display_labyrinth(grid, start, end, solution)
